# %%
import torch

# %%
x = torch.ones(3,5,3,4)
y = 2*torch.ones(3,5,3,4)
y.shape
# Out:
# torch.Size([3, 5, 3, 4])

# %%
from einops import rearrange, einsum, reduce

# z = einsum(x, y, "batch seq1 hidden, batch seq2 hidden -> batch seq1 seq2")
z = einsum(x, y, "... seq1 hidden, ... seqs2 hidden -> ... seq1 seq2")
z2 = rearrange(x, "seq1 seq2 ... -> seq2 seq1 ...")
z3 = reduce(x, "seq1 seq2 ... -> seq2 ...", "sum")
print(z.shape, z2.shape, z3.shape)
# Out:
# ---------------------------------------------------------------------------
# EinopsError                               Traceback (most recent call last)
# Cell In[32], line 4
#       1 from einops import rearrange, einsum, reduce
#       2
#       3 # z = einsum(x, y, "batch seq1 hidden, batch seq2 hidden -> batch seq1 seq2")
# ----> 4 z = einsum(x, y, "... seq1 hidden, ... seqs2 hidden -> ... seq1 seq2")
#       5 z2 = rearrange(x, "seq1 seq2 ... -> seq2 seq1 ...")
#       6 z3 = reduce(x, "seq1 seq2 ... -> seq2 ...", "sum")
#       7 print(z.shape, z2.shape, z3.shape)
#
# File ~/courses/cs336/assignment1-basics/.venv/lib/python3.13/site-packages/einops/einops.py:938, in einsum(*tensors_and_pattern)
#     934     raise ValueError(
#     935         "The last argument passed to `einops.einsum` must be a string, representing the einsum pattern."
#     936     )
#     937 tensors = tensors_and_pattern[:-1]
# --> 938 pattern = _compactify_pattern_for_einsum(pattern)
# ...

# %%
# Out:
# torch.Size([3, 5, 3, 4])
